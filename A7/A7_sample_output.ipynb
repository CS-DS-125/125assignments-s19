# %%
# Out:
# ...
# Welcome to DataGuppies!
# ...
# Please enter a filename to load data for the game: fandango_score_comparison.csv
# Please enter player 1's name: Mark
# Please enter player 2's name: Also Mark
# --------------------------------------------------
# Problem 0:
# Mark, please enter your correlation guess: ···
# Also Mark, please enter your correlation guess: ·
# The actual value is: 0.11230317001899819
#
# Mark was closest!
# Press enter to continue...
# --------------------------------------------------
# Problem 1:
# Mark, please enter your correlation guess: ···
# Also Mark, please enter your correlation guess: ···
# The actual value is: 0.6929539176056567
#
# Mark was closest!
# Press enter to continue...
# --------------------------------------------------
# Problem 2:
# Mark, please enter your correlation guess: ·
# Also Mark, please enter your correlation guess: ···
# The actual value is: 0.9902986817302504
#
# Mark was closest!
# Press enter to continue...
# ...

# %%
# Out:
# ...
# Welcome to DataGuppies!
# ...
# Please enter a filename to load data for the game: fandango_score_comparison.csv
# Please enter player 1's name: Mark
# Please enter player 2's name: Also Mark
# --------------------------------------------------
# Problem 0:
# Mark, please enter your correlation guess: ···
# Also Mark, please enter your correlation guess: ····
# The actual value is: -0.08529787879628659
#
# Also Mark was closest!
# Press enter to continue...
# --------------------------------------------------
# Problem 1:
# Mark, please enter your correlation guess: ···
# Also Mark, please enter your correlation guess: ···
# The actual value is: 0.95735958811599
#
# Also Mark was closest!
# Press enter to continue...
# --------------------------------------------------
# Problem 2:
# Mark, please enter your correlation guess: ··
# Also Mark, please enter your correlation guess: ····
# The actual value is: -0.8414418513648819
#
# Mark was closest!
# Press enter to continue...
# ...
